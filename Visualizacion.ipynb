# %% [markdown]
# ## VISUALIZACION CON MATPLOTLIB

# %%
import numpy as np
import pandas as pd
import copy as cp
import matplotlib.pyplot as plt

# %% [markdown]
# Información fuente para trabajar

# %%
dt=pd.read_csv('5m Sales Records.csv',sep=';',header=0,nrows=100000)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Region          100000 non-null  object
#  1   Country         100000 non-null  object
#  2   Item Type       100000 non-null  object
#  3   Sales Channel   100000 non-null  object
#  4   Order Priority  100000 non-null  object
#  5   Order Date      100000 non-null  object
#  6   Order ID        100000 non-null  int64
#  7   Ship Date       100000 non-null  object
#  8   Units Sold      100000 non-null  int64
#  9   Unit Price      100000 non-null  float64
#  10  Unit Cost       100000 non-null  float64
#  11  Total Revenue   100000 non-null  float64
#  12  Total Cost      100000 non-null  float64
#  13  Total Profit    100000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 10.7+ MB

# %% [markdown]
# ## PYPLOT BASICO

# %%
X=np.linspace(0,5,11)
Y=X**2

# %%
plt.plot(X,Y,'bo--')
plt.show()

# %%
plt.boxplot(dt['Total Profit'])
plt.show()

# %%
plt.hist(dt['Total Profit'])
plt.show()

# %%
plt.scatter(dt['Total Cost'],dt['Total Profit'])
plt.show()

# %% [markdown]
# #### Subplot

# %%
plt.subplot(1,2,1)
plt.hist(dt['Total Profit'])
plt.subplot(1,2,2)
plt.boxplot(dt['Total Profit'])

plt.show()

# %% [markdown]
# ### Graficos orientados a objetos

# %%
fig=plt.figure()
# axes son los objetos tipo figura
# fig.add_axes([a,b,c,d]) a y b indican la posicion en el lienzo, c y d el tamaño.
axes=fig.add_axes([0.1,0.1,0.5,0.5]) 
axes.plot(X,Y,'b--')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.5,0.5]) 
axes2=fig.add_axes([0.15,0.35,0.15,0.2]) 
axes.plot(X,Y,'b--')
axes2.plot(Y,X,'r-')
axes2.set_facecolor('green')

# %% [markdown]
# ### Subplots (orientado a objetos)

# %%
fig, axes=plt.subplots(1,2)
axes[0].plot(Y,X,'c--')
axes[1].plot(X,Y,'r-')

# %% [markdown]
# De igual forma si se asignan nombres G1 y G2 a cada salida

# %%
fig, (G1,G2)=plt.subplots(1,2)
G1.plot(Y,X,'c--')
G2.plot(X,Y,'r-')
fig.tight_layout()  # Ajuste automatico de espacios

# %% [markdown]
# ### TEXTO EN LA GRAFICA

# %%
fig, axes=plt.subplots(1,2,figsize=(8,4))
axes[0].plot(Y,X,'co-',mfc='w',label="$\sqrt{y}$")
axes[0].set_title('Funcion A')
axes[0].set_xlabel('Eje x')
axes[0].set_ylabel('Eje y')
axes[0].legend()

axes[1].plot(X,Y,'rs:',mfc='y',label="$x^2$")
axes[1].set_title('Funcion B')
axes[1].set_xlabel('Eje 1')
axes[1].set_ylabel('Eje 2')
axes[1].legend()

# %% [markdown]
# ### Colores
