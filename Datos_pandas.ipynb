# %% [markdown]
# # DECLARACION MANUAL DE DATAFRAME

# %%
import numpy as np
import pandas as pd
import copy as cp

# %% [markdown]
# * Series

# %%
S01=pd.Series(['Galaxias','Cumulos estelares','Estrellas'],index=[1,5,3])
print('\n Declaracion manual del panda series controlando el index \n',S01)
# Out:
#  Declaracion manual del panda series controlando el index
#  1             Galaxias
# 5    Cumulos estelares
# 3            Estrellas
# dtype: object

# %%
S02=pd.Series(['Galaxias','Cumulos estelares','Estrellas'])
print('\n Declaracion manual del panda series index automatico \n',S02)
# Out:
#  Declaracion manual del panda series index automatico
#  0             Galaxias
# 1    Cumulos estelares
# 2            Estrellas
# dtype: object

# %% [markdown]
# Usando diccionarios para definir una serie

# %%
dic01={1:'Galaxias',5:'Cumulos estelares',3:'Estrellas'}
S03=pd.Series(dic01)
print('\n Declaracion de uan serie desde un diccionario \n',S03)
# Out:
#  Declaracion de uan serie desde un diccionario
#  1             Galaxias
# 5    Cumulos estelares
# 3            Estrellas
# dtype: object

# %% [markdown]
# Para acceder a los elementos, se realiza mediante los valores del index así:

# %%
print('\nAcceso al elemento con index=5: ',S03[5])
# Out:
# Acceso al elemento con index=5:  Cumulos estelares

# %% [markdown]
# * Declaracion manual de dataframes desde un diccioario

# %%
dic02={'Objeto':['Galaxias','Cumulos estelares','Estrellas'],
'Tipos':[5,3,12],
'Escala_pc':[50,10,1]}
print('\n Diccionario fuente: \n',dic02)
dt01=pd.DataFrame(dic02,index=[1,5,3])  # Indice manual
dt02=pd.DataFrame(dic02)                # Indice automatico  
print('\n Dataframe: \n',dt01,'\n\n',dt02)
# Out:
#  Diccionario fuente:
#  {'Objeto': ['Galaxias', 'Cumulos estelares', 'Estrellas'], 'Tipos': [5, 3, 12], 'Escala_pc': [50, 10, 1]}
#
#  Dataframe:
#                Objeto  Tipos  Escala_pc
# 1           Galaxias      5         50
# 5  Cumulos estelares      3         10
# 3          Estrellas     12          1
#
#                Objeto  Tipos  Escala_pc
# 0           Galaxias      5         50
# 1  Cumulos estelares      3         10
# 2          Estrellas     12          1

# %%
print('\nColumnas del dataframe\n',dt01.columns)
print('\nIndices del dataframe\n',dt01.index)
print('\nIndices del dataframe\n',dt02.index)
# Out:
# Columnas del dataframe
#  Index(['Objeto', 'Tipos', 'Escala_pc'], dtype='object')
#
# Indices del dataframe
#  Int64Index([1, 5, 3], dtype='int64')
#
# Indices del dataframe
#  RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# # LECTURA DE DATOS

# %%
dt03=pd.read_csv('5m Sales Records.csv',sep=';',header=0,nrows=500)

# %%
print('\n Columnas \n',dt03.columns)
print(list(dt03.columns))
dt03.dtypes
# Out:
#  Columnas
#  Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')
# ['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority', 'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %% [markdown]
# * Filtros con loc iloc

# %%
# Seleccion de variables
dt03[['Country','Item Type']]
# Out:
#                              Country        Item Type
# 0                              Palau  Office Supplies
# 1                             Poland        Beverages
# 2                             Canada           Cereal
# 3                            Belarus           Snacks
# 4                               Oman           Cereal
# 5                       Burkina Faso  Office Supplies
# 6                         Montenegro    Personal Care
# 7                         Azerbaijan        Cosmetics
# 8                        South Sudan          Clothes
# 9                          Greenland    Personal Care
# 10                          Portugal        Cosmetics
# 11                      Sierra Leone          Clothes
# 12                           Germany    Personal Care
# 13                        Montenegro    Personal Care
# 14                        Bangladesh           Cereal
# 15                        Mauritius            Snacks
# ...

# %% [markdown]
# Usando loc para filtrar registros

# %%
# Filtro por indice y seleccion de dos columnas especificas
dt03.loc[10:20,['Country','Item Type']]
# Out:
#          Country      Item Type
# 10      Portugal      Cosmetics
# 11  Sierra Leone        Clothes
# 12       Germany  Personal Care
# 13    Montenegro  Personal Care
# 14    Bangladesh         Cereal
# 15    Mauritius          Snacks
# 16    Kyrgyzstan         Snacks
# 17    Madagascar        Clothes
# 18       Romania           Meat
# 19         Malta  Personal Care
# 20        Latvia        Clothes

# %%
# Filtro por condiciones sobre una o mas columnas
dt04=dt03.loc[:,['Item Type']]=='Meat'
dt04
# Out:
#     Item Type
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False

# %%
dt03.iloc[2:5,:]
# Out:
#                          Region  Country Item Type Sales Channel  \
# 2                 North America   Canada    Cereal        Online
# 3                        Europe  Belarus    Snacks        Online
# 4  Middle East and North Africa     Oman    Cereal       Offline
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 2              M   1/8/2015  504055583  1/31/2015         103      205.70
# 3              C  1/19/2014  954955518  2/27/2014        1414      152.58
# 4              H  4/26/2019  970755660   6/2/2019        7027      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 2     117.11       21187.10    12062.33       9124.77
# 3      97.44      215748.12   137780.16      77967.96
# 4     117.11     1445453.90   822931.97     622521.93

# %% [markdown]
# * Eliminar columnas

# %%
# En este caso el cambio queda en la salida pero no en el dataframe original dt03 en este caso
dt03.drop('Order ID',axis=1)
print(dt03.columns)
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
# Para que la eliminacion quede en el dataframe se incluye inplace=True
dt03.drop('Order ID',axis=1,inplace=True)

# %%
print(dt03.columns)
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Ship Date', 'Units Sold', 'Unit Price', 'Unit Cost',
#        'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %% [markdown]
# * Eliminar filas o registros

# %%
dt03.drop(0,axis=0).head(2)
# Out:
#           Region Country  Item Type Sales Channel Order Priority Order Date  \
# 1         Europe  Poland  Beverages        Online              L  4/18/2010
# 2  North America  Canada     Cereal        Online              M   1/8/2015
#
#    Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 1  5/26/2010        9340       47.45      31.79       443183.0   296918.60
# 2  1/31/2015         103      205.70     117.11        21187.1    12062.33
#
#    Total Profit
# 1     146264.40
# 2       9124.77

# %% [markdown]
# * Adicionar columnas

# %%
dt03['tax']=0.16*dt03['Total Cost']
dt03.head(10)
# Out:
#                          Region       Country        Item Type Sales Channel  \
# 0         Australia and Oceania         Palau  Office Supplies        Online
# 1                        Europe        Poland        Beverages        Online
# 2                 North America        Canada           Cereal        Online
# 3                        Europe       Belarus           Snacks        Online
# 4  Middle East and North Africa          Oman           Cereal       Offline
# 5            Sub-Saharan Africa  Burkina Faso  Office Supplies        Online
# 6                        Europe    Montenegro    Personal Care        Online
# 7  Middle East and North Africa    Azerbaijan        Cosmetics       Offline
# 8            Sub-Saharan Africa   South Sudan          Clothes       Offline
# 9                 North America     Greenland    Personal Care        Online
#
#   Order Priority  Order Date   Ship Date  Units Sold  Unit Price  Unit Cost  \
# ...

# %% [markdown]
# * Adicionar registros

# %%
# Revisar-----------------<<<<<<<<<<<<<<<
dt04=dt03.head(3)
#dt04.index=[5000001,5000002,500003]
#dt05=pd.concat(dt03,dt04)
#dt05.tail(10)

# %% [markdown]
# # MANEJO DE DATOS NULOS

# %%
dic03={'Objeto':['Galaxias','Cumulos estelares','Estrellas','Quasars','Nebulosas'],
'Tipos':[5,np.nan,12,4,2],
'Escala_pc':[50,10,1,np.nan,15]}
print('\n Diccionario fuente: \n',dic03)
dt06=pd.DataFrame(dic03)
print(dt06)
# Out:
#  Diccionario fuente:
#  {'Objeto': ['Galaxias', 'Cumulos estelares', 'Estrellas', 'Quasars', 'Nebulosas'], 'Tipos': [5, nan, 12, 4, 2], 'Escala_pc': [50, 10, 1, nan, 15]}
#               Objeto  Tipos  Escala_pc
# 0           Galaxias    5.0       50.0
# 1  Cumulos estelares    NaN       10.0
# 2          Estrellas   12.0        1.0
# 3            Quasars    4.0        NaN
# 4          Nebulosas    2.0       15.0

# %%
print(dt06.isnull())
# Out:
#    Objeto  Tipos  Escala_pc
# 0   False  False      False
# 1   False   True      False
# 2   False  False      False
# 3   False  False       True
# 4   False  False      False

# %%
dt06.fillna('NA')
# Out:
#               Objeto Tipos Escala_pc
# 0           Galaxias   5.0      50.0
# 1  Cumulos estelares    NA      10.0
# 2          Estrellas  12.0       1.0
# 3            Quasars   4.0        NA
# 4          Nebulosas   2.0      15.0

# %% [markdown]
# # FILTRADO

# %%
# Creando la condicion
cond01=dt03['Order Priority']=='H'
dt03[cond01]
# Haciendolo de forma directa
dt03[dt03['Order Priority']=='H']
# Out:
#                                Region               Country        Item Type  \
# 0               Australia and Oceania                 Palau  Office Supplies
# 4        Middle East and North Africa                  Oman           Cereal
# 6                              Europe            Montenegro    Personal Care
# 12                             Europe               Germany    Personal Care
# 16                               Asia            Kyrgyzstan           Snacks
# 19                             Europe                 Malta    Personal Care
# 20                             Europe                Latvia          Clothes
# 23                               Asia               Myanmar       Vegetables
# 25                             Europe                Russia           Fruits
# 28  Central America and the Caribbean                Belize           Fruits
# 35                             Europe              Slovenia        Cosmetics
# ...

# %%
# Mas de una condicion de filtro con Y
cond02=dt03['Region']=='Europe'
dt03[cond01 & cond02]
# Out:
#     Region         Country      Item Type Sales Channel Order Priority  \
# 6   Europe      Montenegro  Personal Care        Online              H
# 12  Europe         Germany  Personal Care       Offline              H
# 19  Europe           Malta  Personal Care       Offline              H
# 20  Europe          Latvia        Clothes        Online              H
# 25  Europe          Russia         Fruits       Offline              H
# 35  Europe        Slovenia      Cosmetics        Online              H
# 37  Europe  United Kingdom  Personal Care       Offline              H
# 39  Europe          Poland        Clothes        Online              H
#
#     Order Date   Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 6   11/24/2012  12/25/2012        1337       81.73      56.67      109273.01
# 12  12/25/2010   1/24/2011        7722       81.73      56.67      631119.06
# 19   5/21/2012   6/22/2012        6473       81.73      56.67      529038.29
# ...

# %%
# Mas de una condicion de filtro con O
dt03[cond01 | cond02]
# Out:
#                                Region               Country        Item Type  \
# 0               Australia and Oceania                 Palau  Office Supplies
# 1                              Europe                Poland        Beverages
# 3                              Europe               Belarus           Snacks
# 4        Middle East and North Africa                  Oman           Cereal
# 6                              Europe            Montenegro    Personal Care
# 10                             Europe              Portugal        Cosmetics
# 12                             Europe               Germany    Personal Care
# 13                             Europe            Montenegro    Personal Care
# 16                               Asia            Kyrgyzstan           Snacks
# 18                             Europe               Romania             Meat
# 19                             Europe                 Malta    Personal Care
# ...

# %%
# Negacion de condiciones de filtro
dt03[~cond01 | ~cond02]
# Out:
#                                Region                           Country  \
# 0               Australia and Oceania                             Palau
# 1                              Europe                            Poland
# 2                       North America                            Canada
# 3                              Europe                           Belarus
# 4        Middle East and North Africa                              Oman
# 5                  Sub-Saharan Africa                      Burkina Faso
# 7        Middle East and North Africa                        Azerbaijan
# 8                  Sub-Saharan Africa                       South Sudan
# 9                       North America                         Greenland
# 10                             Europe                          Portugal
# 11                 Sub-Saharan Africa                      Sierra Leone
# 13                             Europe                        Montenegro
# ...

# %% [markdown]
# # FUNCIONES PRINCIPALES DE PANDAS

# %%
dt03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          50 non-null     object
#  1   Country         50 non-null     object
#  2   Item Type       50 non-null     object
#  3   Sales Channel   50 non-null     object
#  4   Order Priority  50 non-null     object
#  5   Order Date      50 non-null     object
#  6   Ship Date       50 non-null     object
#  7   Units Sold      50 non-null     int64
#  8   Unit Price      50 non-null     float64
#  9   Unit Cost       50 non-null     float64
#  10  Total Revenue   50 non-null     float64
#  11  Total Cost      50 non-null     float64
#  12  Total Profit    50 non-null     float64
#  13  tax             50 non-null     float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 5.6+ KB

# %%
dt03.describe()
# Out:
#         Units Sold  Unit Price   Unit Cost  Total Revenue    Total Cost  \
# count    50.000000   50.000000   50.000000   5.000000e+01  5.000000e+01
# mean   5095.600000  274.271000  189.940400   1.356520e+06  9.259584e+05
# std    2814.017681  232.291458  184.865713   1.412514e+06  1.080526e+06
# min     103.000000    9.330000    6.920000   5.831250e+03  4.325000e+03
# 25%    2804.750000   81.730000   56.670000   4.137199e+05  1.935402e+05
# 50%    4451.000000  154.060000   97.440000   8.402883e+05  4.339504e+05
# 75%    7217.250000  437.200000  263.330000   1.723753e+06  1.337747e+06
# max    9917.000000  668.270000  524.960000   5.868079e+06  4.412804e+06
#
#        Total Profit            tax
# count  5.000000e+01      50.000000
# mean   4.305615e+05  148153.346496
# std    3.917709e+05  172884.093636
# min    1.506250e+03     692.000000
# 25%    1.484411e+05   30966.425200
# 50%    2.940158e+05   69432.062400
# 75%    5.784625e+05  214039.469600
# ...

# %%
# Uso de memoria
dt03.memory_usage()
# Out:
# Index             128
# Region            400
# Country           400
# Item Type         400
# Sales Channel     400
# Order Priority    400
# Order Date        400
# Ship Date         400
# Units Sold        400
# Unit Price        400
# Unit Cost         400
# Total Revenue     400
# Total Cost        400
# Total Profit      400
# tax               400
# dtype: int64

# %%
# Frecuencias de variables categoricas
dt03['Item Type'].value_counts()
# Out:
# Personal Care      7
# Cosmetics          7
# Office Supplies    6
# Snacks             5
# Clothes            5
# Fruits             4
# Household          4
# Beverages          3
# Cereal             3
# Vegetables         3
# Baby Food          2
# Meat               1
# Name: Item Type, dtype: int64

# %%
# Creacion de duplicados
dt07=dt03.append(dt03.iloc[0])
dt07.drop_duplicates()
# Out:
# /tmp/ipykernel_3421/3091244971.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dt07=dt03.append(dt03.iloc[0])
#                                Region                           Country  \
# 0               Australia and Oceania                             Palau
# 1                              Europe                            Poland
# 2                       North America                            Canada
# 3                              Europe                           Belarus
# 4        Middle East and North Africa                              Oman
# 5                  Sub-Saharan Africa                      Burkina Faso
# 6                              Europe                        Montenegro
# 7        Middle East and North Africa                        Azerbaijan
# 8                  Sub-Saharan Africa                       South Sudan
# ...

# %% [markdown]
#   ## Ordenar el dataframe

# %%
dt03.sort_values('Country')
# Out:
#                                Region                           Country  \
# 49  Central America and the Caribbean              Antigua and Barbuda
# 7        Middle East and North Africa                        Azerbaijan
# 21                               Asia                        Bangladesh
# 14                               Asia                        Bangladesh
# 3                              Europe                           Belarus
# 28  Central America and the Caribbean                            Belize
# 5                  Sub-Saharan Africa                      Burkina Faso
# 2                       North America                            Canada
# 40                 Sub-Saharan Africa                           Comoros
# 34                 Sub-Saharan Africa  Democratic Republic of the Congo
# 44                             Europe                            France
# 12                             Europe                           Germany
# ...

# %% [markdown]
# ## Agrupamiento

# %%
dt03.groupby('Sales Channel').sum()
# Out:
# /tmp/ipykernel_3421/2098668147.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dt03.groupby('Sales Channel').sum()
#                Units Sold  Unit Price  Unit Cost  Total Revenue   Total Cost  \
# Sales Channel
# Offline             96782     3970.04    2590.99    19643649.03  12484357.04
# Online             157998     9743.51    6906.03    48182344.60  33813563.74
#
#                Total Profit           tax
# Sales Channel
# Offline          7159291.99  1.997497e+06
# Online          14368780.86  5.410170e+06

# %%
dt03.groupby('Sales Channel').agg(['min','max'])
# Out:
#               Region                                   Country  \
#                  min                 max                   min
# Sales Channel
# Offline         Asia  Sub-Saharan Africa            Azerbaijan
# Online          Asia  Sub-Saharan Africa  Antigua and Barbuda
#
#                                Item Type             Order Priority      \
#                           max        min         max            min max
# Sales Channel
# Offline        United Kingdom  Beverages  Vegetables              C   M
# Online                 Zambia  Baby Food  Vegetables              C   M
#
#                Order Date             ... Unit Cost         Total Revenue  \
#                       min        max  ...       min     max           min
# Sales Channel                         ...
# Offline        10/19/2012   9/7/2019  ...      6.92  524.96      25629.51
# Online          1/19/2014  9/22/2016  ...      6.92  524.96       5831.25
#
# ...

# %%
dt03.groupby('Region').agg({'Unit Cost':'mean','Total Profit':['min','max']})
# Out:
#                                     Unit Cost Total Profit
#                                          mean          min         max
# Region
# Asia                                72.932857      1506.25   369061.00
# Australia and Oceania              278.375000     76217.22   303126.25
# Central America and the Caribbean  222.960000      8755.53  1455275.13
# Europe                             168.201111      6620.27  1264034.90
# Middle East and North Africa       293.700000    106374.05  1338625.13
# North America                       86.890000      9124.77    81169.34
# Sub-Saharan Africa                 233.105000    218523.20  1155540.02

# %%
dt08=dt03.groupby(['Region','Order Priority']).sum()
print(dt08)
# Out:
#                                                   Units Sold  Unit Price  \
# Region                            Order Priority
# Asia                              C                     9898        9.33
#                                   H                     8161      306.64
#                                   L                     8891      517.76
# Australia and Oceania             C                     4867       47.45
#                                   H                     2401      651.21
# Central America and the Caribbean H                    12414      677.60
#                                   M                     8553      255.28
# Europe                            C                     5185     1258.05
#                                   H                    39051      992.01
#                                   L                    20321     1217.59
#                                   M                    18528     1013.15
# ...

# %% [markdown]
# ## COMBINANDO DATAFRAMES

# %%
# Concatenacion de dataframes
dt09=pd.DataFrame({'Pais':['Colombia','Perú','Ecuador','Bolivia','Venezuela','Paraguay','Nicaragua'],
                   'Capital':['Bogotá','Lima','Quito','La Paz','Caracas','Asuncion','Managua']})
dt10=pd.DataFrame({'Pais':['Colombia','Perú','Ecuador','Bolivia','Venezuela','Paraguay','El salvador'],
                   'Pob (Mill)':[43,8,6,5,29,11,4]})
dt11=pd.DataFrame({'Pais':['Brasil','Argentina','Chile','Uruguay','Panama'],
                   'Capital':['Brasilia','Buenos aires','Santiago de chile','Montevideo','Panama']})

# %%
# axis indica la dimension en la cual se realiza la concatenacion 0= filas 1= columnas
dt12=pd.concat([dt09,dt11],axis=0)
dt12
# Out:
#         Pais            Capital
# 0   Colombia             Bogotá
# 1       Perú               Lima
# 2    Ecuador              Quito
# 3    Bolivia             La Paz
# 4  Venezuela            Caracas
# 5   Paraguay           Asuncion
# 0     Brasil           Brasilia
# 1  Argentina       Buenos aires
# 2      Chile  Santiago de chile
# 3    Uruguay         Montevideo
# 4     Panama             Panama

# %% [markdown]
# ## Combinacion de dataframes con MERGE

# %%
# Combinacion de dos dataframe
dt13=dt09.merge(dt10)  # POr defecto realiza un inner join
dt13
# Out:
#         Pais   Capital  Pob (Mill)
# 0   Colombia    Bogotá          43
# 1       Perú      Lima           8
# 2    Ecuador     Quito           6
# 3    Bolivia    La Paz           5
# 4  Venezuela   Caracas          29
# 5   Paraguay  Asuncion          11

# %%
# La instrccion on indica la variable sobre la cual se realiza el merge, pero esta deberá se comun a los dos dataframes.
dt14=dt09.merge(dt10,on='Pais') 
dt14
# Out:
#         Pais   Capital  Pob (Mill)
# 0   Colombia    Bogotá          43
# 1       Perú      Lima           8
# 2    Ecuador     Quito           6
# 3    Bolivia    La Paz           5
# 4  Venezuela   Caracas          29
# 5   Paraguay  Asuncion          11

# %%
# En caso que los campos llave no tengan el mismo nombre, se debe especificar por separado.
dt15=pd.DataFrame({'Paises':['Colombia','Perú','Ecuador','Bolivia','Venezuela','Paraguay','El salvador'],
                   'Pob (Mill)':[43,8,6,5,29,11,4]})
dt16=dt09.merge(dt15,left_on='Pais',right_on='Paises')
dt16
# Out:
#         Pais   Capital     Paises  Pob (Mill)
# 0   Colombia    Bogotá   Colombia          43
# 1       Perú      Lima       Perú           8
# 2    Ecuador     Quito    Ecuador           6
# 3    Bolivia    La Paz    Bolivia           5
# 4  Venezuela   Caracas  Venezuela          29
# 5   Paraguay  Asuncion   Paraguay          11

# %%
# En caso que algunos valores de los campos llave sean NA, entonces solo se traen los registros con llave valida
dt17=pd.DataFrame({'Paises':['Colombia',np.nan,'Ecuador','Bolivia','Venezuela','Paraguay','El salvador'],
                   'Pob (Mill)':[43,8,6,5,29,11,4]})
dt18=dt09.merge(dt17,left_on='Pais',right_on='Paises')
# La salida ya no contiene a Perú
dt18
# Out:
#         Pais   Capital     Paises  Pob (Mill)
# 0   Colombia    Bogotá   Colombia          43
# 1    Ecuador     Quito    Ecuador           6
# 2    Bolivia    La Paz    Bolivia           5
# 3  Venezuela   Caracas  Venezuela          29
# 4   Paraguay  Asuncion   Paraguay          11

# %%
# Para otros tipos de join se debe usar el comando how asi:
# En caso que los campos llave no tengan el mismo nombre, se debe especificar por separado.
dt15=pd.DataFrame({'Paises':['Colombia','Perú','Ecuador','Bolivia','Venezuela','Paraguay','El salvador'],
                   'Pob (Mill)':[43,8,6,5,29,11,4]})
dt19=dt09.merge(dt15,left_on='Pais',right_on='Paises',how='left')
dt19
# Out:
#         Pais   Capital     Paises  Pob (Mill)
# 0   Colombia    Bogotá   Colombia        43.0
# 1       Perú      Lima       Perú         8.0
# 2    Ecuador     Quito    Ecuador         6.0
# 3    Bolivia    La Paz    Bolivia         5.0
# 4  Venezuela   Caracas  Venezuela        29.0
# 5   Paraguay  Asuncion   Paraguay        11.0
# 6  Nicaragua   Managua        NaN         NaN

# %%
dt20=dt09.merge(dt15,left_on='Pais',right_on='Paises',how='right')
dt20
# Out:
#         Pais   Capital       Paises  Pob (Mill)
# 0   Colombia    Bogotá     Colombia          43
# 1       Perú      Lima         Perú           8
# 2    Ecuador     Quito      Ecuador           6
# 3    Bolivia    La Paz      Bolivia           5
# 4  Venezuela   Caracas    Venezuela          29
# 5   Paraguay  Asuncion     Paraguay          11
# 6        NaN       NaN  El salvador           4

# %% [markdown]
# En el caso de hacer combinacion de Dataframes con JOIN solo se debe tener encueta que por defecto esta instrucción realiza la combinacion usando los index de cada dataframe.

# %% [markdown]
# ## REESTRUCTURACION DE UN DATAFRAME

# %% [markdown]
# ### PIVOT_TABLE

# %%
dt21=dt03.pivot_table(index=['Item Type'],columns='Region',values='Total Profit',aggfunc='sum')
print(dt21)
# Out:
# Index(['Asia', 'Australia and Oceania', 'Central America and the Caribbean',
#        'Europe', 'Middle East and North Africa', 'North America',
#        'Sub-Saharan Africa'],
#       dtype='object', name='Region')

# %% [markdown]
# ### MELT

# %%
dt22=dt03.melt(id_vars=['Order Priority','Sales Channel'],value_vars='Item Type')
print(dt22)
# Out:
#     Order Priority Sales Channel   variable            value
# 0                H        Online  Item Type  Office Supplies
# 1                L        Online  Item Type        Beverages
# 2                M        Online  Item Type           Cereal
# 3                C        Online  Item Type           Snacks
# 4                H       Offline  Item Type           Cereal
# ..             ...           ...        ...              ...
# 495              C       Offline  Item Type           Snacks
# 496              H       Offline  Item Type        Beverages
# 497              C        Online  Item Type        Baby Food
# 498              H        Online  Item Type    Personal Care
# 499              H        Online  Item Type        Household
#
# [500 rows x 4 columns]

# %% [markdown]
# ### APPLY

# %%
def ttimes(x):
    return x*1.19

dt03['Iva']=dt03['Total Cost'].apply(ttimes)
print(dt03.head(5))
# Out:
#                          Region  Country        Item Type Sales Channel  \
# 0         Australia and Oceania    Palau  Office Supplies        Online
# 1                        Europe   Poland        Beverages        Online
# 2                 North America   Canada           Cereal        Online
# 3                        Europe  Belarus           Snacks        Online
# 4  Middle East and North Africa     Oman           Cereal       Offline
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H   3/6/2016  517073523  3/26/2016        2401      651.21
# 1              L  4/18/2010  380507028  5/26/2010        9340       47.45
# 2              M   1/8/2015  504055583  1/31/2015         103      205.70
# 3              C  1/19/2014  954955518  2/27/2014        1414      152.58
# 4              H  4/26/2019  970755660   6/2/2019        7027      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit           Iva
# ...
